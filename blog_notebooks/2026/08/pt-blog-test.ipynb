# %% [raw]
# ---
# title: "Checking automated blog pipeline manually"
# date: "2026-08-22"
# date-format: "MMMM DD, YYYY"
# execute:
#   enabled: false
# ---

# %% [raw]
# <style>
# .quarto-title-meta-heading { display: none; }
# .quarto-title-meta { margin-top: 0.75em; }
# .quarto-title-meta-contents .date { font-size: 0.85em; color: #888; }
# .colab-badge-row { text-align: right; margin-bottom: 1em; }
# </style>

# %% [raw]
# <div class="colab-badge-row">
# <a href="https://colab.research.google.com/github/tripathyp/tripathyp.github.io/blob/main/blog_notebooks/2026/08/pt-blog-test.ipynb" target="_blank" rel="noopener noreferrer"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
# </div>

# %% [markdown]
# This is my first blog test!

# %%
# comment code using this
print("\n".join([
    f'{a **  2}'
    for a in range (1, 11)
]))
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100

# %% [markdown]
# More narrative text can go here, interleaved with further code cells as needed.

# %%
import matplotlib.pyplot as plt

x = list(range(10))
y = [v ** 2 for v in x]
plt.plot(x, y, marker="o")
plt.title("A simple test plot by Pratyush")
plt.show()
