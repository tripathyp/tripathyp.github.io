# %% [raw]
# ---
# title: "REPLACE ME: Post Title"
# date: "REPLACE-WITH-YYYY-MM-DD"
# date-format: "MMMM DD, YYYY"
# execute:
#   enabled: false
# ---

# %% [raw]
# <style>
# .quarto-title-meta-heading { display: none; }
# .quarto-title-meta { margin-top: 0.75em; }
# .quarto-title-meta-contents .date { font-size: 0.85em; color: #888; }
# .colab-badge-row { text-align: right; margin-bottom: 1em; }
# </style>

# %% [raw]
# <div class="colab-badge-row">
# <a href="https://colab.research.google.com/github/tripathyp/tripathyp.github.io/blob/main/REPLACE/WITH/PATH.ipynb" target="_blank" rel="noopener noreferrer"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
# </div>

# %% [markdown]
# Write your intro text here. Regular markdown cells like this one become plain text
# paragraphs in the rendered post.

# %%
# Code cells like this run and their output (text, plots, tables) is embedded
# directly below them in the rendered post.
print("hello from the template notebook")

# %% [markdown]
# More narrative text can go here, interleaved with further code cells as needed.
